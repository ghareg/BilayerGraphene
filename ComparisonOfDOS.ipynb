# %%
import numpy as np
from scipy.signal import savgol_filter
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
#matplotlib.rc('font', **font)
cstring = 'rgbcmyk'
import matplotlib as ml
# %matplotlib inline
ml.rcParams['figure.figsize'] = (8.0, 5.0)
ml.rcParams['text.usetex'] =True
ml.rc('font', family='serif',size=20)

# %%
dpath = "/home/aghazary/Documents/StonerBilayerData/"
with open(dpath+'U0.0KV0.0KDataABGrapheneABC.npy', 'rb') as f:
    a4AB = np.load(f)
dmu = 0.002
DlistAB =np.arange(0,120.1,0.5)
mulAB = np.arange(-150,150.0001,dmu)
mulAB = mulAB[1:-1]
nuTAB = a4AB[:,1:-1]
dosAB = (a4AB[:,2:]-a4AB[:,0:-2]) / (2*dmu)
fdtAB = np.array([interp1d(nuTAB[i], dosAB[i], kind='linear') for i in range(len(nuTAB))])

# %%
dpath = "/home/aghazary/Documents/StonerData/"
dmu = 0.005
mulABC = np.arange(-70,60.0001,dmu)
DlistABC = np.arange(0,60.1,0.5)
with open(dpath+'U0.0KV0.0KDatag2m15dtm105Dt2m23.npy', 'rb') as f:
    a4ABC = np.load(f)
mulABC = mulABC[1:-1]
nuTABC = a4ABC[:,1:-1]
dosABC = (a4ABC[:,2:]-a4ABC[:,0:-2]) / (2*dmu)
fdtABC = np.array([interp1d(nuTABC[i], dosABC[i], kind='linear') for i in range(len(nuTABC))])

# %%
dpath = "/home/aghazary/Documents/StonerABCData/"
dmu = 0.002
mulABC = np.arange(-150,150.0001,dmu)
DlistABC = np.arange(0,120.1,0.5)
with open(dpath+'U0.0KV0.0KDataABCGraphene.npy', 'rb') as f:
    a4ABC = np.load(f)
mulABC = mulABC[1:-1]
nuTABC = a4ABC[:,1:-1]
dosABC = (a4ABC[:,2:]-a4ABC[:,0:-2]) / (2*dmu)
fdtABC = np.array([interp1d(nuTABC[i], dosABC[i], kind='linear') for i in range(len(nuTABC))])

# %%
dpath = "/home/aghazary/Documents/StonerABAData/"
dmu = 0.002
mulABA = np.arange(-150,150.0001,dmu)
DlistABA = np.arange(0,120.1,0.5)
with open(dpath+'U0.0KV0.0KDataABAGrapheneABC.npy', 'rb') as f:
    a4ABA = np.load(f)
mulABA = mulABA[1:-1]
nuTABA = a4ABA[:,1:-1]
dosABA = (a4ABA[:,2:]-a4ABA[:,0:-2]) / (2*dmu)
fdtABA = np.array([interp1d(nuTABA[i], dosABA[i], kind='linear') for i in range(len(nuTABA))])

# %%
dpath = "/home/aghazary/Documents/MyWorks/TrilayerGraphene/CFiles/DOSCodeABA/"
dmu = 0.001
mulABA0 = np.arange(-70,70.0001,dmu)
DlistABA0 = np.arange(0,60.1,0.5)
with open(dpath+'DOSND1000kmax0.12T0.03Zibrov.npy', 'rb') as f:
    a4ABA0 = np.load(f)
mulABA0 = mulABA0[1:-1]
nuTABA0 = a4ABA0[:,1:-1]
dosABA0 = (a4ABA0[:,2:]-a4ABA0[:,0:-2]) / (2*dmu)
fdtABA0 = np.array([interp1d(nuTABA0[i], dosABA0[i], kind='linear') for i in range(len(nuTABA0))])

# %%
dpath = "/home/aghazary/Documents/StonerABABData/"
with open(dpath+'U0.0KV0.0KDataABABGrapheneABCNewParam.npy', 'rb') as f:
    a4ABAB = np.load(f)
dmu = 0.002
DlistABAB =np.arange(0,40.1,0.25)#np.arange(0,120.1,0.5)
mulABAB = np.arange(-150,150.0001,dmu)
mulABAB = mulABAB[1:-1]
nuTABAB = a4ABAB[:,1:-1]
dosABAB = (a4ABAB[:,2:]-a4ABAB[:,0:-2]) / (2*dmu)
fdtABAB = np.array([interp1d(nuTABAB[i], dosABAB[i], kind='linear') for i in range(len(nuTABAB))])

# %%
dpath = "/home/aghazary/Documents/StonerABCAData/"
with open(dpath+'U0.0KV0.0KDataABCAGrapheneABCNewParam.npy', 'rb') as f:
    a4ABCA = np.load(f)
dmu = 0.002
DlistABCA =3*np.arange(0,40.1,0.25)#np.arange(0,120.1,0.5)
mulABCA = np.arange(-150,150.0001,dmu)
mulABCA = mulABCA[1:-1]
nuTABCA = a4ABCA[:,1:-1]
dosABCA = (a4ABCA[:,2:]-a4ABCA[:,0:-2]) / (2*dmu)
fdtABCA = np.array([interp1d(nuTABCA[i], dosABCA[i], kind='linear') for i in range(len(nuTABCA))])

# %%
dpath = "/home/aghazary/Documents/StonerABCABData/"
with open(dpath+'U0.0KV0.0KDataABCABGrapheneABCP.npy', 'rb') as f:
    a4ABCAB = np.load(f)
dmu = 0.002
DlistABCAB =np.arange(0,120.1,0.5)#np.arange(0,120.1,0.5)
mulABCAB = np.arange(-150,150.0001,dmu)
mulABCAB = mulABCAB[1:-1]
nuTABCAB = a4ABCAB[:,1:-1]
dosABCAB = (a4ABCAB[:,2:]-a4ABCAB[:,0:-2]) / (2*dmu)
fdtABCAB = np.array([interp1d(nuTABCAB[i], dosABCAB[i], kind='linear') for i in range(len(nuTABCAB))])

# %%
dpath = "/home/aghazary/Documents/StonerABCAData/"
with open(dpath+'U0.0KV0.0KDataABCAGrapheneABCZoom6080.npy', 'rb') as f:
    a4ABCA1 = np.load(f)
dmu = 0.002
DlistABCA1 =np.arange(60,80.1,0.125)#np.arange(0,120.1,0.5)
mulABCA1 = np.arange(-150,150.0001,dmu)
mulABCA1 = mulABCA1[1:-1]
nuTABCA1 = a4ABCA1[:,1:-1]
dosABCA1 = (a4ABCA1[:,2:]-a4ABCA1[:,0:-2]) / (2*dmu)
fdtABCA1 = np.array([interp1d(nuTABCA1[i], dosABCA1[i], kind='linear') for i in range(len(nuTABCA1))])

# %%
dpath = "/home/aghazary/Documents/StonerABACData/"
with open(dpath+'U0.0KV0.0KDataABACGrapheneABCNewParam.npy', 'rb') as f:
    a4ABAC = np.load(f)
dmu = 0.002
DlistABAC =np.arange(-40,40.1,0.25)#np.arange(0,120.1,0.5)
mulABAC = np.arange(-150,150.0001,dmu)
mulABAC = mulABAC[1:-1]
nuTABAC = a4ABAC[:,1:-1]
dosABAC = (a4ABAC[:,2:]-a4ABAC[:,0:-2]) / (2*dmu)
fdtABAC = np.array([interp1d(nuTABAC[i], dosABAC[i], kind='linear') for i in range(len(nuTABAC))])
fdeABAC = np.array([interp1d(mulABAC, nuTABAC[i], kind='linear') for i in range(len(nuTABAC))])

# %%
a=2.46
Au = np.sqrt(3) * a**2 / 2
mult=Au*0.1

# %%
from matplotlib.gridspec import GridSpec
ml.rcParams['figure.figsize'] = (16.0, 14.0)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(3, 1, figure=fig)
nul = np.arange(-3.0,2.0,0.001)

Dl=30
indAB=np.where(np.abs(np.abs(Dl)-DlistAB)<0.01)[0][0]
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABA=np.where(np.abs(np.abs(Dl)-DlistABA)<0.01)[0][0]
indABAB=np.where(np.abs(np.abs(Dl//3)-DlistABAB)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl//3)-DlistABCA)<0.01)[0][0]
indABAC=np.where(np.abs(np.abs(Dl//3)+DlistABAC)<0.01)[0][0]
ax1 = fig.add_subplot(gs[0, :])
ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=22)
ax1.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=22)
ax1.plot(nul, Au*0.1*fdtAB[indAB](nul),'b',label=r'AB')
ax1.plot(nul, Au*0.1*fdtABA[indABA](nul),'r',label=r'ABA')
ax1.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'ABC')
ax1.plot(nul, Au*0.1*fdtABAB[indABAB](nul),'m',label=r'ABAB')
ax1.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'ABCA')
ax1.plot(nul, Au*0.1*fdtABAC[indABAC](nul),'g',label=r'ABAC')
ax1.set_xlim([-3.0,2.0])
ax1.set_yticks([0,0.4,0.8,1.2])
ax1.set_ylim([0,1.0])
ax1.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=22)
ax1.legend(frameon=False,fontsize=20)

Dl=60
indAB=np.where(np.abs(np.abs(Dl)-DlistAB)<0.01)[0][0]
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABA=np.where(np.abs(np.abs(Dl)-DlistABA)<0.01)[0][0]
indABAB=np.where(np.abs(np.abs(Dl//3)-DlistABAB)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl//3)-DlistABCA)<0.01)[0][0]
indABAC=np.where(np.abs(np.abs(Dl//3)+DlistABAC)<0.01)[0][0]
ax2 = fig.add_subplot(gs[1, :])
ax2.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=22)
ax2.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=22)
ax2.plot(nul, Au*0.1*fdtAB[indAB](nul),'b',label=r'AB')
ax2.plot(nul, Au*0.1*fdtABA[indABA](nul),'r',label=r'ABA')
ax2.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'ABC')
ax2.plot(nul, Au*0.1*fdtABAB[indABAB](nul),'m',label=r'ABAB')
ax2.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'ABCA')
ax2.plot(nul, Au*0.1*fdtABAC[indABAC](nul),'g',label=r'ABAC')
ax2.set_xlim([-3.0,2.0])
ax2.set_yticks([0,0.8,1.6,2.4])
ax2.set_ylim([0,2.6])
ax2.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=22)
ax2.legend(frameon=False,fontsize=20)

Dl=90
nul = np.arange(-3.0,2.0,0.001)
indAB=np.where(np.abs(np.abs(Dl)-DlistAB)<0.01)[0][0]
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABA=np.where(np.abs(np.abs(Dl)-DlistABA)<0.01)[0][0]
indABAB=np.where(np.abs(np.abs(Dl//3)-DlistABAB)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl//3)-DlistABCA)<0.01)[0][0]
indABAC=np.where(np.abs(np.abs(Dl//3)+DlistABAC)<0.01)[0][0]
ax3 = fig.add_subplot(gs[2, :])
ax3.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=22)
ax3.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=22)
ax3.plot(nul, Au*0.1*fdtAB[indAB](nul),'b',label=r'AB')
ax3.plot(nul, Au*0.1*fdtABA[indABA](nul),'r',label=r'ABA')
ax3.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'ABC')
ax3.plot(nul, Au*0.1*fdtABAB[indABAB](nul),'m',label=r'ABAB')
ax3.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'ABCA')
ax3.plot(nul, Au*0.1*fdtABAC[indABAC](nul),'g',label=r'ABAC')
ax3.set_xlim([-3.0,2.0])
ax3.set_yticks([0,0.4,0.8,1.2,1.6])
ax3.set_ylim([0,2.6])
ax3.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=22)
ax3.legend(frameon=False,fontsize=20)

#plt.savefig('DOSComparison.pdf')

# %%
from matplotlib.gridspec import GridSpec
ml.rcParams['figure.figsize'] = (16.0, 9.0)
ml.rcParams['axes.linewidth'] = 1.5
ml.rc('font', family='serif',size=24)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(2, 1, figure=fig,hspace=0.1,wspace=0.01)
nul = np.arange(-3.0,3.0,0.001)

Dl=0
indAB=np.where(np.abs(np.abs(Dl)-DlistAB)<0.01)[0][0]
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABA=np.where(np.abs(np.abs(Dl)-DlistABA)<0.01)[0][0]
indABAB=np.where(np.abs(np.abs(Dl//3)-DlistABAB)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl//3)-DlistABCA)<0.01)[0][0]
indABACp=np.where(np.abs(np.abs(Dl//3)-DlistABAC)<0.01)[0][0]
indABACn=np.where(np.abs(np.abs(Dl//3)+DlistABAC)<0.01)[0][0]
ax1 = fig.add_subplot(gs[0, :])
#ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=22)
ax1.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=28)
ax1.plot(nul, Au*0.1*fdtAB[indAB](nul),'b',label=r'${\rm AB}$')
ax1.plot(nul, Au*0.1*fdtABA[indABA](nul),'r',label=r'${\rm ABA}$')
ax1.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'${\rm ABC}$')
ax1.plot(nul, Au*0.1*fdtABAB[indABAB](nul),'m',label=r'${\rm ABAB}$')
ax1.plot(nul, Au*0.1*fdtABAC[indABACp](nul),'g',label=r'${\rm ABAC_+}$')
ax1.plot(nul, Au*0.1*fdtABAC[indABACn](nul),'y',label=r'${\rm ABAC_-}$')
ax1.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'${\rm ABCA}$')
ax1.set_xlim([-3.0,3.0])
ax1.set_xticks([])
ax1.set_yticks([0,0.4,0.8,1.2])
ax1.set_ylim([0,1.0])
#ax1.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=22)
ax1.legend(frameon=False,fontsize=22,loc='upper right')

Dl=60
indAB=np.where(np.abs(np.abs(Dl)-DlistAB)<0.01)[0][0]
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABA=np.where(np.abs(np.abs(Dl)-DlistABA)<0.01)[0][0]
indABAB=np.where(np.abs(np.abs(Dl//3)-DlistABAB)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl//3)-DlistABCA)<0.01)[0][0]
indABACp=np.where(np.abs(np.abs(Dl//3)-DlistABAC)<0.01)[0][0]
indABACn=np.where(np.abs(np.abs(Dl//3)+DlistABAC)<0.01)[0][0]
ax2 = fig.add_subplot(gs[1, :])
ax2.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=28)
ax2.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=28)
ax2.plot(nul, Au*0.1*fdtAB[indAB](nul),'b',label=r'${\rm AB}$')
ax2.plot(nul, Au*0.1*fdtABA[indABA](nul),'r',label=r'${\rm ABA}$')
ax2.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'${\rm ABC}$')
ax2.plot(nul, Au*0.1*fdtABAB[indABAB](nul),'m',label=r'${\rm ABAB}$')
ax2.plot(nul, Au*0.1*fdtABAC[indABACp](nul),'g',label=r'${\rm ABAC_+}$')
ax2.plot(nul, Au*0.1*fdtABAC[indABACn](nul),'y',label=r'${\rm ABAC_-}$')
ax2.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'${\rm ABCA}$')
ax2.set_xlim([-3.0,3.0])
ax2.set_yticks([0,1.0,2.0,3.0])
ax2.set_ylim([0,3.0])
#ax1.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=22)
ax2.legend(frameon=False,fontsize=22,loc='upper right')

ax1.text(-3.4, 0.95, r"{\bf(a)}", fontsize=30, weight='bold')
ax2.text(-3.4,2.95, r"{\bf(b)}", fontsize=30, weight='bold')

#plt.savefig('DOSComparison.pdf')
# Out:
# Text(-3.4, 2.95, '{\\bf(b)}')

# %%
from matplotlib.gridspec import GridSpec
ml.rcParams['figure.figsize'] = (9.3, 3.7)
ml.rcParams['axes.linewidth'] = 1.5
ml.rc('font', family='serif',size=24)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)

Dl=60
indAB=np.where(np.abs(np.abs(Dl)-DlistAB)<0.01)[0][0]
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABA=np.where(np.abs(np.abs(Dl)-DlistABA)<0.01)[0][0]
indABAB=np.where(np.abs(np.abs(Dl//3)-DlistABAB)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl//3)-DlistABCA)<0.01)[0][0]
indABACp=np.where(np.abs(np.abs(Dl//3)-DlistABAC)<0.01)[0][0]
indABACn=np.where(np.abs(np.abs(Dl//3)+DlistABAC)<0.01)[0][0]
ax2 = fig.subplots(1,1)
ax2.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=28)
ax2.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=28)
ax2.plot(nul, Au*0.1*fdtAB[indAB](nul),'b',label=r'${\rm AB}$')
#ax2.plot(nul, Au*0.1*fdtABA[indABA](nul),'r',label=r'${\rm ABA}$')
ax2.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'${\rm ABC}$')
#ax2.plot(nul, Au*0.1*fdtABAB[indABAB](nul),'m',label=r'${\rm ABAB}$')
ax2.plot(nul, Au*0.1*fdtABAC[indABACp](nul),'g',label=r'${\rm ABAC_+}$')
ax2.plot(nul, Au*0.1*fdtABAC[indABACn](nul),'y',label=r'${\rm ABAC_-}$')
ax2.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'${\rm ABCA}$')
ax2.set_xlim([-3.0,3.0])
#ax2.set_yticks([0,0.1,0.2,0.3])
ax2.set_yticks([0,1.0,2.0,3.0])
ax2.set_ylim([0,3.0])
#ax2.set_xticks([])
#ax1.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=22)
ax2.legend(frameon=False,fontsize=22,loc='upper right',bbox_to_anchor=(0.27,1.08))
plt.savefig('DOSLargeD30.pdf')

# %%
from matplotlib.gridspec import GridSpec
ml.rcParams['figure.figsize'] = (9.3, 11)
ml.rcParams['axes.linewidth'] = 1.5
ml.rc('font', family='serif',size=24)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(3, 1, figure=fig)
nul = np.arange(-3.0,3.0,0.001)

ax1 = fig.add_subplot(gs[0, :])
Dl=42
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl)-DlistABCA)<0.01)[0][0]
indABCAB=np.where(np.abs(np.abs(Dl)-DlistABCAB)<0.01)[0][0]
ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=28)
ax1.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=28)
ax1.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'${\rm ABC}$')
ax1.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'${\rm ABCA}$')
ax1.plot(nul, Au*0.1*fdtABCAB[indABCAB](nul),'r',label=r'${\rm ABCAB}$')
ax1.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=24)
ax1.set_xlim([-3.0,3.0])
ax1.set_yticks([0,0.5,1.0])
ax1.set_ylim([0,1.0])
ax1.legend(frameon=False,fontsize=22,loc='upper right',bbox_to_anchor=(0.28,1.08))


Dl=72
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl)-DlistABCA)<0.01)[0][0]
indABCAB=np.where(np.abs(np.abs(Dl)-DlistABCAB)<0.01)[0][0]
ax2 = fig.add_subplot(gs[1, :])
ax2.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=28)
ax2.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=28)
ax2.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'${\rm ABC}$')
ax2.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'${\rm ABCA}$')
ax2.plot(nul, Au*0.1*fdtABCAB[indABCAB](nul),'r',label=r'${\rm ABCAB}$')
ax2.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=24)
ax2.set_xlim([-3.0,3.0])
ax2.set_yticks([0,1.0,2.0,3.0])
ax2.set_ylim([0,3.0])
ax2.legend(frameon=False,fontsize=22,loc='upper right',bbox_to_anchor=(0.28,1.08))

Dl=108
indABC=np.where(np.abs(np.abs(Dl)-DlistABC)<0.01)[0][0]
indABCA=np.where(np.abs(np.abs(Dl)-DlistABCA)<0.01)[0][0]
indABCAB=np.where(np.abs(np.abs(Dl)-DlistABCAB)<0.01)[0][0]
ax3 = fig.add_subplot(gs[2, :])
ax3.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=28)
ax3.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=28)
ax3.plot(nul, Au*0.1*fdtABC[indABC](nul),'k',label=r'${\rm ABC}$')
ax3.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'c',label=r'${\rm ABCA}$')
ax3.plot(nul, Au*0.1*fdtABCAB[indABCAB](nul),'r',label=r'${\rm ABCAB}$')
ax3.set_title('$\Delta_1=%.1f\,\mathrm{meV}$' %(Dl),fontsize=24)
ax3.set_xlim([-3.0,3.0])
ax3.set_yticks([0,0.5,1.0,1.5])
ax3.set_ylim([0,1.5])
ax3.legend(frameon=False,fontsize=22,loc='upper right',bbox_to_anchor=(0.28,1.08))
#plt.savefig('DOSComparison1.pdf')

# %%
DlistABCA
# Out:
# array([  0.  ,   0.75,   1.5 ,   2.25,   3.  ,   3.75,   4.5 ,   5.25,
#          6.  ,   6.75,   7.5 ,   8.25,   9.  ,   9.75,  10.5 ,  11.25,
#         12.  ,  12.75,  13.5 ,  14.25,  15.  ,  15.75,  16.5 ,  17.25,
#         18.  ,  18.75,  19.5 ,  20.25,  21.  ,  21.75,  22.5 ,  23.25,
#         24.  ,  24.75,  25.5 ,  26.25,  27.  ,  27.75,  28.5 ,  29.25,
#         30.  ,  30.75,  31.5 ,  32.25,  33.  ,  33.75,  34.5 ,  35.25,
#         36.  ,  36.75,  37.5 ,  38.25,  39.  ,  39.75,  40.5 ,  41.25,
#         42.  ,  42.75,  43.5 ,  44.25,  45.  ,  45.75,  46.5 ,  47.25,
#         48.  ,  48.75,  49.5 ,  50.25,  51.  ,  51.75,  52.5 ,  53.25,
#         54.  ,  54.75,  55.5 ,  56.25,  57.  ,  57.75,  58.5 ,  59.25,
#         60.  ,  60.75,  61.5 ,  62.25,  63.  ,  63.75,  64.5 ,  65.25,
#         66.  ,  66.75,  67.5 ,  68.25,  69.  ,  69.75,  70.5 ,  71.25,
#         72.  ,  72.75,  73.5 ,  74.25,  75.  ,  75.75,  76.5 ,  77.25,
# ...

# %%
ll=mulABAB.shape[0]
plt.plot(mulABAB[ll//2+1400:],dosABAB[0,ll//2+1400:])

# %%
mulABAB[ll//2+1400:][np.argmin(dosABAB[0,ll//2+1400:])]
# Out:
# 7.498000000752029

# %%
indABACn=np.where(np.abs(np.abs(120//3)+DlistABAC)<0.01)[0][0]
plt.scatter(mulABAC,dosABAC[indABACn])
#plt.xlim([-20.7,-19.5])
#plt.ylim([-3,-2])

# %%
from matplotlib.gridspec import GridSpec
ml.rcParams['figure.figsize'] = (16.0, 9.0)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(2, 1, figure=fig)
nul = np.arange(-3.0,2.5,0.001)

Dln=20
Dl=3*Dln
indABCA=np.where(np.abs(np.abs(Dl)-DlistABCA)<0.01)[0][0]
indABAC=np.where(np.abs(np.abs(Dln)-DlistABAC)<0.01)[0][0]
ax1 = fig.add_subplot(gs[0, :])
ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=22)
ax1.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=22)
ax1.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'b',label=r'$\Delta_1=%.1f\,\mathrm{meV}\,\left(\mathrm{Old}\right)$' %(Dl))
ax1.plot(nul, Au*0.1*fdtABAC[indABAC](nul),'r',label=r'$\Delta_1=%.1f\,\mathrm{meV}\,\left(\mathrm{New}\right)$' %(Dln))
ax1.set_xlim([-3.0,2.5])
ax1.set_yticks([0,0.5,1.0,1.5,2.0,2.5])
ax1.set_ylim([0,2.5])
ax1.legend(frameon=False,fontsize=20)

Dln=25
Dl=3*Dln
indABCA=np.where(np.abs(np.abs(Dl)-DlistABCA)<0.01)[0][0]
indABAC=np.where(np.abs(np.abs(Dln)-DlistABAC)<0.01)[0][0]
ax2 = fig.add_subplot(gs[1, :])
ax2.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=22)
ax2.set_ylabel(r'$\rho\, \left({\rm eV}^{-1} A^{-1}_{\rm u.c.}\right)$',fontsize=22)
ax2.plot(nul, Au*0.1*fdtABCA[indABCA](nul),'b',label=r'$\Delta_1=%.1f\,\mathrm{meV}\,\left(\mathrm{Old}\right)$' %(Dl))
ax2.plot(nul, Au*0.1*fdtABAC[indABAC](nul),'r',label=r'$\Delta_1=%.1f\,\mathrm{meV}\,\left(\mathrm{New}\right)$' %(Dln))
ax2.set_xlim([-3.0,2.5])
ax2.set_yticks([0,0.5,1.0,1.5,2.0])
ax2.set_ylim([0,1.5])
ax2.legend(frameon=False,fontsize=20)



plt.savefig('DOSComparison.png',dpi=200)

# %%
DlistABAC[82]
# Out:
# -19.5

# %%
ml.rcParams['figure.figsize'] = (16.0, 4.0)
nul = np.arange(-6.0,3.5,0.001)
plt.scatter(nuTABAC[80], fdtABAC[80](nuTABAC[80]))
#plt.plot(nul, fdtABA0[40](nul))

# %%
plt.scatter(mulABAC,nuTABAC[80])
plt.plot(mulABAC,dosABAC[80])
plt.xlim([-20.1,-19.9])
plt.ylim([-3,-2.4])
# Out:
# (-3.0, -2.4)

# %%
mulABAC[np.argmax(fdtABAC[80](nuTABAC[80]))]
# Out:
# -19.99999999937927

# %%
dpath = "/home/aghazary/Documents/MyWorks/BilayerGraphene/PythonCode/SuperABCA/"
with open(dpath+'EnergyDif.npy', 'rb') as f:
    dat = np.load(f,allow_pickle=True)
Dtl=np.arange(1,18.01,1)
datn=[dat[np.where(np.abs(Dtll-dat[:,0])<1e-6)[0]] for Dtll in Dtl]
minp=np.array([datn[i][5+np.argmin(datn[i][5:,2])] for i in range(len(datn))])

# %%
minden=np.array([[Dtl[i], fdeABAC[np.where(np.abs(np.abs(Dtl[i])-Dlist)<0.01)[0][0]](minp[i,1])] for i in range(len(Dtl))])

# %%
from matplotlib.gridspec import GridSpec
ml.rc('font', family='serif',size=18)
ml.rcParams['figure.figsize'] = (12.0, 4.0)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(1, 1, figure=fig)
Dlist =np.arange(0,120.1,0.5)
ax1 = fig.add_subplot(gs[0, 0])
nul = np.arange(-3.0,2.51,0.001)
Dfl = np.arange(0,120+0.1,0.5)
ind = np.where(np.abs(np.abs(Dfl[-1])-Dlist)<0.01)[0][0]


ax1 = fig.add_subplot(gs[0, 0])
Cpl = (10 / Au)*np.array([1/(0.001+fdtAB[i](nul)) for i in range(ind+1)])
vmax = np.amax(Cpl)
vmin = np.amin(Cpl)
cmap = plt.get_cmap('PiYG')
xi, yi = np.meshgrid(Dfl,nul)
vml = 0.0
vxl = 20
pc =ax1.pcolormesh(yi,xi,np.transpose(Cpl),cmap=cmap,vmin=vml,vmax=vxl,rasterized=True)
ax1.plot([-2,-2],[0,100],'r')
ax1.plot([-1.1,-1.1],[0,65],'r')
ax1.set_ylim([0,120])
ax1.set_xlim([nul[0],nul[-1]])
ax1.set_ylabel(r'$\Delta_1\,\left({\rm meV}\right)$',fontsize=20)
ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=20)
ax1.set_title(r'AB',fontsize=20)
cbaxes = fig.add_axes([0.94, 0.435, 0.01, 0.24])
cbar=plt.colorbar(pc, orientation="vertical",cax=cbaxes)
ax1.text(2.8, 36.5, r'$\kappa\,\left({\rm eV} \cdot A_{\rm u.c.}\right)$',rotation=90)
cbar.ax.tick_params(size=0)
# Out:
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
from matplotlib.gridspec import GridSpec
ml.rc('font', family='serif',size=18)
ml.rcParams['figure.figsize'] = (12.0, 4.0)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(1, 1, figure=fig)
Dlist =np.arange(0,120.1,0.5)
ax1 = fig.add_subplot(gs[0, 0])
nul = np.arange(-3.0,2.51,0.001)
Dfl = np.arange(0,120+0.1,0.5)
ind = np.where(np.abs(np.abs(Dfl[-1])-Dlist)<0.01)[0][0]


ax1 = fig.add_subplot(gs[0, 0])
Cpl = (10 / Au)*np.array([1/(0.001+fdtABC[i](nul)) for i in range(ind+1)])
vmax = np.amax(Cpl)
vmin = np.amin(Cpl)
cmap = plt.get_cmap('PiYG')
xi, yi = np.meshgrid(Dfl,nul)
vml = 0.0
vxl = 10
pc =ax1.pcolormesh(yi,xi,np.transpose(Cpl),cmap=cmap,vmin=vml,vmax=vxl,rasterized=True)
ax1.plot([-1.67,-1.67],[0,80],'r')
ax1.plot([-1.0,-1.0],[0,40],'r')
ax1.set_ylim([0,120])
ax1.set_xlim([nul[0],nul[-1]])
ax1.set_ylabel(r'$\Delta_1\,\left({\rm meV}\right)$',fontsize=20)
ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=20)
ax1.set_title(r'ABC',fontsize=20)
cbaxes = fig.add_axes([0.94, 0.435, 0.01, 0.24])
cbar=plt.colorbar(pc, orientation="vertical",cax=cbaxes)
ax1.text(2.8, 36.5, r'$\kappa\,\left({\rm eV} \cdot A_{\rm u.c.}\right)$',rotation=90)
cbar.ax.tick_params(size=0)
# Out:
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
Dl=100
ind = np.where(np.abs(Dl-DlistAB)<0.01)[0][0]
plt.plot(nul, (10 / Au)/(0.001+fdtAB[ind](nul)))
plt.ylim([0,20])
# Out:
# (0.0, 20.0)

# %%
from matplotlib.gridspec import GridSpec
ml.rc('font', family='serif',size=18)
ml.rcParams['figure.figsize'] = (12.0, 4.0)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(1, 1, figure=fig)
Dlist =np.arange(0,120.1,0.75)
ax1 = fig.add_subplot(gs[0, 0])
nul = np.arange(-3.0,2.51,0.001)
Dfl = np.arange(0,120+0.1,0.75)
ind = np.where(np.abs(np.abs(Dfl[-1])-Dlist)<0.01)[0][0]


ax1 = fig.add_subplot(gs[0, 0])
Cpl = (10 / Au)*np.array([1/(0.001+fdtAB[i](nul)) for i in range(ind+1)])
vmax = np.amax(Cpl)
vmin = np.amin(Cpl)
cmap = plt.get_cmap('PiYG')
xi, yi = np.meshgrid(Dfl,nul)
vml = 0.0
vxl = 20
pc =ax1.pcolormesh(yi,xi,np.transpose(Cpl),cmap=cmap,vmin=vml,vmax=vxl,rasterized=True)
ax1.set_ylim([0,120])
ax1.set_xlim([nul[0],nul[-1]])
ax1.set_ylabel(r'$\Delta_1\,\left({\rm meV}\right)$',fontsize=20)
ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=20)
ax1.set_title(r'ABC',fontsize=20)
cbaxes = fig.add_axes([0.94, 0.735, 0.01, 0.24])
cbar=plt.colorbar(pc, orientation="vertical",cax=cbaxes)
ax1.text(2.8, 36.5, r'$\kappa\,\left({\rm eV} \cdot A_{\rm u.c.}\right)$',rotation=90)
cbar.ax.tick_params(size=0)
# Out:
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
from matplotlib.gridspec import GridSpec
ml.rc('font', family='serif',size=18)
ml.rcParams['figure.figsize'] = (12.0, 12.0)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(3, 1, figure=fig)
Dlist =np.arange(0,120.1,0.75)
ax1 = fig.add_subplot(gs[0, 0])
nul = np.arange(-3.0,2.51,0.001)
Dfl = np.arange(0,120+0.1,0.75)
ind = np.where(np.abs(np.abs(Dfl[-1])-Dlist)<0.01)[0][0]


ax1 = fig.add_subplot(gs[0, 0])
Cpl = (10 / Au)*np.array([1/(0.001+fdtABC[i](nul)) for i in range(ind+1)])
vmax = np.amax(Cpl)
vmin = np.amin(Cpl)
cmap = plt.get_cmap('PiYG')
xi, yi = np.meshgrid(Dfl,nul)
vml = 0.0
vxl = 1
pc =ax1.pcolormesh(yi,xi,np.transpose(Cpl),cmap=cmap,vmin=vml,vmax=vxl,rasterized=True)
ax1.set_ylim([0,120])
ax1.set_xlim([nul[0],nul[-1]])
ax1.set_ylabel(r'$\Delta_1\,\left({\rm meV}\right)$',fontsize=20)
ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=20)
ax1.set_title(r'ABC',fontsize=20)
cbaxes = fig.add_axes([0.94, 0.735, 0.01, 0.24])
cbar=plt.colorbar(pc, orientation="vertical",cax=cbaxes)
ax1.text(2.8, 36.5, r'$\kappa\,\left({\rm eV} \cdot A_{\rm u.c.}\right)$',rotation=90)
cbar.ax.tick_params(size=0)


ax2 = fig.add_subplot(gs[1, 0])
Cpl = (10 / Au)*np.array([1/(0.001+fdtABCA[i](nul)) for i in range(ind+1)])
vmax = np.amax(Cpl)
vmin = np.amin(Cpl)
cmap = plt.get_cmap('PiYG')
xi, yi = np.meshgrid(Dfl,nul)
vml = 0.0
vxl = 1
pc =ax2.pcolormesh(yi,xi,np.transpose(Cpl),cmap=cmap,vmin=vml,vmax=vxl,rasterized=True)
ax2.set_ylim([0,120])
ax2.set_xlim([nul[0],nul[-1]])
ax2.set_ylabel(r'$\Delta_1\,\left({\rm meV}\right)$',fontsize=20)
ax2.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=20)
ax2.set_title(r'ABCA',fontsize=20)
cbaxes = fig.add_axes([0.94, 0.40, 0.01, 0.24])
cbar=plt.colorbar(pc, orientation="vertical",cax=cbaxes)
ax2.text(2.8, 36.5, r'$\kappa\,\left({\rm eV} \cdot A_{\rm u.c.}\right)$',rotation=90)
cbar.ax.tick_params(size=0)


ax3 = fig.add_subplot(gs[2, 0])
Cpl = (10 / Au)*np.array([1/(0.001+fdtABCAB[i](nul)) for i in range(ind+1)])
vmax = np.amax(Cpl)
vmin = np.amin(Cpl)
cmap = plt.get_cmap('PiYG')
xi, yi = np.meshgrid(Dfl,nul)
vml = 0.0
vxl = 1
pc =ax3.pcolormesh(yi,xi,np.transpose(Cpl),cmap=cmap,vmin=vml,vmax=vxl,rasterized=True)
ax3.set_ylim([0,120])
ax3.set_xlim([nul[0],nul[-1]])
ax3.set_ylabel(r'$\Delta_1\,\left({\rm meV}\right)$',fontsize=20)
ax3.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=20)
ax3.set_title(r'ABCAB',fontsize=20)
cbaxes = fig.add_axes([0.94, 0.065, 0.01, 0.24])
cbar=plt.colorbar(pc, orientation="vertical",cax=cbaxes)
ax3.text(2.8, 36.5, r'$\kappa\,\left({\rm eV} \cdot A_{\rm u.c.}\right)$',rotation=90)
cbar.ax.tick_params(size=0)
#plt.savefig('PhaseDiagramComp.pdf', dpi=200)
# Out:
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
# ...

# %%
from matplotlib.gridspec import GridSpec
ml.rc('font', family='serif',size=18)
ml.rcParams['figure.figsize'] = (12.0, 4.0)
ml.rcParams['contour.negative_linestyle']= 'solid'
fig = plt.figure(constrained_layout=True)
gs = GridSpec(1, 1, figure=fig)
Dlist =np.arange(60,80.1,0.125)
ax1 = fig.add_subplot(gs[0, 0])
nul = np.arange(0.0,3.01,0.001)
Dfl = np.arange(60,80+0.1,0.125)
ind = np.where(np.abs(np.abs(Dfl[-1])-Dlist)<0.01)[0][0]
Cpl = (10 / Au)*np.array([1/(0.001+fdtABCA1[i](nul)) for i in range(ind+1)])
vmax = np.amax(Cpl)
vmin = np.amin(Cpl)
cmap = plt.get_cmap('PiYG')
xi, yi = np.meshgrid(Dfl,nul)
vml = 0.0
vxl = 1.5
pc =ax1.pcolormesh(yi,xi,np.transpose(Cpl),cmap=cmap,vmin=vml,vmax=vxl,rasterized=True)
ax1.plot([0,4],[67.125,67.125],'r')
#ax1.scatter(minden[:,0],minden[:,1],s=2.5,color='k')
ax1.set_ylim([Dfl[0]-0.0,Dfl[-1]])
ax1.set_xlim([nul[0],nul[-1]])
ax1.set_ylabel(r'$\Delta_1\,\left({\rm meV}\right)$',fontsize=20)
ax1.set_xlabel(r'$n_e\, \left(10^{12}\, {\rm cm}^{-2}\right)$',fontsize=20)
#ax1.set_title(r'$U=0\,\mathrm{eV}$',fontsize=20)
#ax1.set_title(r'ABCA New',fontsize=20)
cbaxes = fig.add_axes([0.91, 0.195, 0.01, 0.77])
cbar=plt.colorbar(pc, orientation="vertical",cax=cbaxes)
ax1.text(3.3, 66.5, r'$\kappa\,\left({\rm eV} \cdot A_{\rm u.c.}\right)$',rotation=90)
cbar.ax.tick_params(size=0)
plt.savefig('ABPhaseDiagram.png', dpi=200)
# Out:
# /home/aghazary/.local/lib/python3.6/site-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
cbaxes = fig.add_axes([1.06, 0.58, 0.3, 0.8])
cbar.ax.tick_params(size=0)
#ax1.text(0.70, 1.3, r'$\kappa\,\left({\rm eV} \cdot A_{\rm u.c.}\right)$')
cbar=plt.colorbar(pc, orientation="vertical",cax=cbaxes)

# %%
ml.rcParams['figure.figsize'] = (12.0, 4.0)
nul = np.arange(-6.0,6.0,0.001)
#plt.plot(nul, Au*0.1*fdtABCA[120](nul))
plt.plot(mulABCA, Au*0.1*dosABCA[120])
plt.xlim([-70,90])
# Out:
# (-70.0, 90.0)

# %%
dpath = "/home/aghazary/Documents/MyWorks/BilayerGraphene/PythonCode/SuperABCA/Data/"
with open(dpath+'LambdaPerfNestElec.npy', 'rb') as f:
    lmbT = np.load(f,allow_pickle=True)

# %%
dlist=np.array([float(lmbT[0][i][0]) for i in range(len(lmbT[0]))])
mulist=np.array([float(lmbT[0][i][1]) for i in range(len(lmbT[0]))])
lmd4list=np.array([lmbT[1][i][0] for i in range(len(lmbT[1]))])
lmd2list=np.array([lmbT[1][i][2] for i in range(len(lmbT[1]))])
psi4list=np.array([lmbT[1][i][1] for i in range(len(lmbT[1]))])
psi2list=np.array([lmbT[1][i][3] for i in range(len(lmbT[1]))])
sizes=np.array([lmbT[1][i][4] for i in range(len(lmbT[1]))])
indsc=np.array([lmbT[1][i][5] for i in range(len(lmbT[1]))])

# %%
ml.rcParams['figure.figsize'] = (8.0, 4.0)
ml.rc('font', family='serif',size=20)
fig, ax=plt.subplots(1,1)
ax.plot(dlist,-lmd4list[:,0],label=r'$N=4$')
ax.plot(dlist,-lmd2list[:,0],label=r'$N=2$')
ax.set_xlim([1.0,18.0])
ax.set_ylim([0,0.07])
ax.set_xlabel(r"$\Delta_1\, \left(\mathrm{meV}\right)$", fontsize=20)
ax.set_ylabel(r"$\lambda$", fontsize=20)
ax.legend(frameon=False,fontsize=20)
plt.tight_layout()
plt.savefig("Sup20ABCA.png",dpi=200)
